# %%
##loading the required libraries
from sklearn import tree
import msmbuilder as msb

# %%
##helper functions 
colorlist=['b', 'g', 'r', 'y']

w=lambda x: np.where(data[:,-1]==x)
w_cls=lambda x: np.where(clf_res==x)

def PlotIthState(i,func=w):
    scatter(data[func(i),0],data[func(i),1],color=colorlist[i],label="State %d"%i)
    axis([-180,180,-180,180])

# %%
mac=msb.io.loadh("MacroAssignments.h5")
NumStates= np.max(mac['Data'])+1
phi=msb.io.loadh("Phi.h5")
psi=msb.io.loadh("Psi.h5")
# Out:
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/msmbuilder-2.7.dev-py2.7-macosx-10.5-x86_64.egg/msmbuilder/io.py:183: DeprecationWarning: openFile() is pending deprecation, use open_file() instead. You may use the pt2to3 tool to update your source code.
#   handle = tables.openFile(file, mode='r')
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/msmbuilder-2.7.dev-py2.7-macosx-10.5-x86_64.egg/msmbuilder/io.py:207: DeprecationWarning: iterNodes() is pending deprecation, use iter_nodes() instead. You may use the pt2to3 tool to update your source code.
#   for node in handle.iterNodes(where='/'):
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/msmbuilder-2.7.dev-py2.7-macosx-10.5-x86_64.egg/msmbuilder/io.py:183: DeprecationWarning: openFile() is pending deprecation, use open_file() instead. You may use the pt2to3 tool to update your source code.
#   handle = tables.openFile(file, mode='r')
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/msmbuilder-2.7.dev-py2.7-macosx-10.5-x86_64.egg/msmbuilder/io.py:207: DeprecationWarning: iterNodes() is pending deprecation, use iter_nodes() instead. You may use the pt2to3 tool to update your source code.
#   for node in handle.iterNodes(where='/'):
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/msmbuilder-2.7.dev-py2.7-macosx-10.5-x86_64.egg/msmbuilder/io.py:183: DeprecationWarning: openFile() is pending deprecation, use open_file() instead. You may use the pt2to3 tool to update your source code.
#   handle = tables.openFile(file, mode='r')
# /Library/Frameworks/EPD64.framework/Versions/7.3/lib/python2.7/site-packages/msmbuilder-2.7.dev-py2.7-macosx-10.5-x86_64.egg/msmbuilder/io.py:207: DeprecationWarning: iterNodes() is pending deprecation, use iter_nodes() instead. You may use the pt2to3 tool to update your source code.
#   for node in handle.iterNodes(where='/'):

# %%
n_traj = np.shape(mac['Data'])[0]
n_frames_per_traj = np.shape(mac['Data'])[1]
n_frames = n_traj*n_frames_per_traj

# %%
##get the data and the noise
data=np.zeros((n_frames,11))

for i in range(100):
    for j in range(501):
        data[i*501+j,0]=phi['Data'][i,j]
        data[i*501+j,1]=psi['Data'][i,j]
        data[i*501+j,2]=np.random.normal()
        data[i*501+j,3]=np.random.normal()
        data[i*501+j,4]=np.random.normal()
        data[i*501+j,5]=np.random.normal()
        data[i*501+j,6]=np.random.normal()
        data[i*501+j,7]=np.random.normal()
        data[i*501+j,8]=np.random.normal()
        data[i*501+j,9]=np.random.normal()
        data[i*501+j,10]=mac['Data'][i,j]

        
data=np.random.permutation(data)
x_all=data[:,:10]
y_all=data[:,10]
#

# %%
##plotting the oiriginal dataset
for i in range(NumStates):
    print(i)
    PlotIthState(i,w)
title("Alanine Dipeptide Macrostates",fontsize=16)
xlabel(r"$\phi (\circ)$",fontsize=30)
ylabel(r"$\psi (\circ)$",fontsize=30)
axis([-180,180,-180,180])
plt.grid()
plt.box()
legend(loc='best')
tight_layout()
savefig("Original_ala.tiff",dpi=300)
# Out:
# 0
# 1
# 2
# 3

# %% [markdown]
# ## starting the Decision Tree analysis

# %%
print "Max_Depth %Error"
for i in range(1,5):
    clf = tree.DecisionTreeClassifier(max_depth=i)
    clf = clf.fit(x_all,y_all)
    clf_res=clf.predict(x_all[:n_frames/2,])

    print "%d\t"%(i),(1-float(np.sum(clf_res==y_all[:n_frames/2]))/len(y_all[:n_frames/2]))*100
# Out:
# Max_Depth %Error
# 1
# 10.1357285429
# 2
# 1.60878243513
# 3
# 0.822355289421
# 4
# 0.642714570858

# %%
plot_step = 1
x_min = -180
x_max = 180
y_min=-180
y_max=180
xx, yy = np.meshgrid(np.arange(x_min, x_max, plot_step), np.arange(y_min, y_max, plot_step))

        # Plot either a single DecisionTreeClassifier or alpha blend the
        # decision surfaces of the ensemble of classifiers
print np.shape(np.c_[xx.ravel(), yy.ravel(),np.reshape(np.random.normal(0,1,129600*8),(129600,8))])
cmap = cm.Greys
if isinstance(clf, tree.DecisionTreeClassifier):
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel(),np.reshape(np.random.normal(0,1,129600*8),(129600,8))])
    Z = Z.reshape(xx.shape)
    cs = contourf(xx, yy, Z,cmap=cmap)

for i in range(NumStates):
    print(i)
    PlotIthState(i,w_cls)
title("Decision Boundaries For Alanine Dipeptide",fontsize=16)
xlabel(r"$\phi (\circ)$",fontsize=30)
ylabel(r"$\psi (\circ)$",fontsize=30)
axis([-180,180,-180,180])
plt.grid()
plt.box()
legend(loc='best')
tight_layout()
savefig("ala_with_boundaries.tiff",dpi=300)
# Out:
# (129600, 10)
# 0
# 1
# 2
# 3

# %%
plot(clf.feature_importances_,c='blue')
box('off')
grid('on')
xlabel("Features",size=20)
ylabel("Gini Importance",size=20)
savefig("gini.tiff",dpi=300)
